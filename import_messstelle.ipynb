# %% [markdown]
# # Aim of This Notebook

# %% [markdown]
# In this notebook, we want to import the "messstelle.csv" file to our Postgres Database
#
#  we need follwing packages:
#
# * Pandas
# * Sqlalchemy

# %%
#importing the packages

import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy
import credential_temp as  creds

# %% [markdown]
# # Data location

# %% [markdown]
#  First, we need to create the path of our data.

# %%
data_in_dir = r"../data/"

gw_station_fname = r"opendata.gw_messstelle.csv"

gw_station_pfname = data_in_dir + gw_station_fname

# %% [markdown]
# ## Read the file
# Don't forget to add the "delimiter", normal csv file's delimiter is "," but in our case it's ";", so we need to assign it.

# %%
df = pd.read_csv(gw_station_pfname, delimiter=';', header='infer')
df.head()
# Out:
#    sl_nr  messstelle_id                 name     e32      n32  gw_stockwerk  \
# 0  67530       32505929  UWB-Ddorf 01285      343064  5678019           1.0
# 1  51044       10446746  60GP012303           292077  5645349           NaN
# 2  51070       87005323  58BP024606           287141  5684635           NaN
# 3  68442       80000290  Krinsend 0079 neu    309490  5678060           1.0
# 4  68518       86583852  WG102GM93-3          316741  5680237           NaN
#
#   grundstueck gemeinde_id gwhorizont_id      gwhorizont  ...  \
# 0                05111000           NaN             NaN  ...
# 1      privat    NL000882             5  Zwischenmittel  ...
# 2      privat    NL001640            6D  Neurather Sand  ...
# 3                05166024           NaN             NaN  ...
# 4      privat    05166032           NaN             NaN  ...
#
#   beobachtung_wasserstand                                        eigentuemer  \
# 0                       -  Stadt Düsseldorf                              ...
# 1                       -  Prov. Limburg (NL)                            ...
# 2                       -  Prov. Limburg (NL)                            ...
# 3                       -  Land NRW                                      ...
# 4                       -  NiederrheinWasser GmbH (ehem. Niederheinwerke)...
#
#                                            betreiber filterlaenge_cm  \
# 0  Stadt Düsseldorf                              ...             NaN
# 1  Prov. Limburg (NL)                            ...           200.0
# 2  Prov. Limburg (NL)                            ...           500.0
# 3                                                NaN             NaN
# 4  NiederrheinWasser GmbH (ehem. Niederheinwerke)...           200.0
#
#   sumpfrohrlaenge_cm ausbaudurchmesser_mm historischer_ruhe_wsp  \
# 0                NaN                  NaN                   NaN
# 1                NaN                  NaN                   NaN
# 2              300.0                  NaN                   NaN
# 3                NaN                  NaN                   NaN
# 4                NaN                 80.0                   NaN
#
#   einbaulaenge_cm oberkante_filter_cm unterkante_filter_cm
# 0             NaN                 NaN                  NaN
# 1         16893.0             -3333.0              -3533.0
# 2         32667.0            -29083.0             -29583.0
# 3          1517.0              4832.0               4832.0
# 4          5400.0              1413.0               1213.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ## data type
#
# e32 and n32 should be int if we want to create geometry columns from them

# %%
df.dtypes
# Out:
# sl_nr                             int64
# messstelle_id                     int64
# name                             object
# e32                              object
# n32                              object
# gw_stockwerk                    float64
# grundstueck                      object
# gemeinde_id                      object
# gwhorizont_id                    object
# gwhorizont                       object
# gwleiter_id                      object
# gwleiter                         object
# einrichtungsgrund                object
# gwk_lage_auf_id                  object
# gwk_lage_id                      object
# gwk_monitoring_auf_id            object
# gwk_monitoring_id                object
# messprogramm                     object
# turnus_wasserstand               object
# freigabe_wstd                    object
# freigabe_chemie                  object
# freigabe_lage                    object
# wasserstandsmessstelle           object
# guetemessstelle                  object
# im_wrrl_messnetz_chemie          object
# im_wrrl_messnetz_wasserstand     object
# messstellenart                   object
# wasserart                        object
# labor                            object
# beobachtung_wasserstand          object
# eigentuemer                      object
# betreiber                        object
# filterlaenge_cm                 float64
# sumpfrohrlaenge_cm              float64
# ausbaudurchmesser_mm            float64
# historischer_ruhe_wsp           float64
# einbaulaenge_cm                 float64
# oberkante_filter_cm             float64
# unterkante_filter_cm            float64
# dtype: object

# %% [markdown]
# ## change some data types
# * e32 to Int
# * n32 to Int
# * drop NA value
#
# First step, we must drop the NA value.
# Second step is some rows the last two digit are xx which means that the exact location is not avaliable.
# Now we need to replace this xx with two digit. These two xx could be in the range of 00 to 99.
# In here we replace the xx with 50

# %%
# drop NA
df = df.dropna(subset=['e32'])
df = df.dropna(subset=['n32'])

# %%
df.e32
# Out:
# 0        343064
# 1        292077
# 2        287141
# 3        309490
# 4        316741
#           ...
# 71115    468938
# 71116    3338xx
# 71117    331861
# 71118    3604xx
# 71119    3379xx
# Name: e32, Length: 71119, dtype: object

# %%
# replace all xx with 50

df.e32 = df['e32'].replace({'xx':'50'}, regex=True)
df.n32 = df['n32'].replace({'xx':'50'}, regex=True)

# %%
# convert e32 and n32 to int
df['e32'] = df['e32'].astype(int)
df['n32'] = df['n32'].astype(int)

# %% [markdown]
# ### Now the e32 and n32 are int

# %%
df.dtypes
# Out:
# sl_nr                             int64
# messstelle_id                     int64
# name                             object
# e32                               int32
# n32                               int32
# gw_stockwerk                    float64
# grundstueck                      object
# gemeinde_id                      object
# gwhorizont_id                    object
# gwhorizont                       object
# gwleiter_id                      object
# gwleiter                         object
# einrichtungsgrund                object
# gwk_lage_auf_id                  object
# gwk_lage_id                      object
# gwk_monitoring_auf_id            object
# gwk_monitoring_id                object
# messprogramm                     object
# turnus_wasserstand               object
# freigabe_wstd                    object
# freigabe_chemie                  object
# freigabe_lage                    object
# wasserstandsmessstelle           object
# guetemessstelle                  object
# im_wrrl_messnetz_chemie          object
# im_wrrl_messnetz_wasserstand     object
# messstellenart                   object
# wasserart                        object
# labor                            object
# beobachtung_wasserstand          object
# eigentuemer                      object
# betreiber                        object
# filterlaenge_cm                 float64
# sumpfrohrlaenge_cm              float64
# ausbaudurchmesser_mm            float64
# historischer_ruhe_wsp           float64
# einbaulaenge_cm                 float64
# oberkante_filter_cm             float64
# unterkante_filter_cm            float64
# dtype: object

# %%
filt = df['n32'] < 100
df[filt]
# Out:
#        sl_nr  messstelle_id                 name  e32  n32  gw_stockwerk  \
# 3895   30991      118820000  WW.GREVEN.DAMM-WAMI   50   50           1.0
# 4510   47647       47202002  Sammelleitung 21-30   50   50           NaN
# 8338   31022      118840009  WW.TELGTE-WAMI        50   50           1.0
# 10889  30882      118260005  WW.LETTE-WAMI         50   50           1.0
# 13335  47709       68013504  WW.HALTERN-BRR E/F    50   50           NaN
# 13414  14582       68012007  WW.HALTERNWEST-MI     50   50           1.0
# 13430  46769       47247101  RM-Moers Gerdt        50   50           NaN
# 17689  47708       68013401  WW.HALTERN-BRR C/D    50   50           NaN
# 19697  31047      118880007  WW.VOHREN-DACK-WAMI   50   50           1.0
# 22201  47658       47299009  RM-Bucholtwelmen      50   50           NaN
# 24185  30917      118550007  WW.COESFELD-ORTWAMI   50   50           1.0
# 24186  30946      118650002  WW.HOHE-WARD-WAMI     50   50           1.0
# 31231  47706       68013206  WW.HALTERN-BRR B      50   50           NaN
# 33129  30831      118010001  WW.RIESENBECK-WAMI    50   50           1.0
# 35558  47636       47199003  Sammelleitung 1-7     50   50           NaN
# 39926  47638       47200005  Sammelleitung 10-20   50   50           NaN
# 39930  47111       36446518  WA-Lörick LR - RMM    50   50           NaN
# 42005  30928      118620009  WW.NEUENKIRCH.-WAMI   50   50           1.0
# 53282  47710       68013607  WW.HALTERN-BRR H/K    50   50           NaN
# 53290  46753       47039000  Mündelheim Rhein      50   50           NaN
# 53347  46215       59621035  RM-Brunnen Stortel    50   50           NaN
# 55287  31046      118871900  WW.WARENDORF-HEMI     50   50           1.0
# 57828  45778      129700800  RM-Zinse              50   50           NaN
# 59702  30979      118810005  WW.ORTHEIDE-WAMI      50   50           1.0
# 61554  30835      118020006  WW.IBBENB.LEHENWAMI   50   50           1.0
# 62093  47705       68013103  WW.HALTERN-BRR A      50   50           NaN
# 66598  46659       36487600  Wittlaer              50   50           NaN
# 66704  47697       68011003  WW.HALTERNHAARD-MI    50   50           NaN
# 70983  47707       68013309  WW.HALTERN-BRR G      50   50           NaN
#
#       grundstueck gemeinde_id gwhorizont_id gwhorizont  ...  \
# 3895                      NaN           NaN        NaN  ...
# 4510                      NaN           NaN        NaN  ...
# 8338                      NaN           NaN        NaN  ...
# 10889                     NaN           NaN        NaN  ...
# 13335                     NaN           NaN        NaN  ...
# 13414                     NaN           NaN        NaN  ...
# 13430                     NaN           NaN        NaN  ...
# 17689                     NaN           NaN        NaN  ...
# 19697                     NaN           NaN        NaN  ...
# 22201                     NaN           NaN        NaN  ...
# 24185                     NaN           NaN        NaN  ...
# 24186                     NaN           NaN        NaN  ...
# 31231                     NaN           NaN        NaN  ...
# 33129                     NaN           NaN        NaN  ...
# 35558                     NaN           NaN        NaN  ...
# 39926                     NaN           NaN        NaN  ...
# 39930                     NaN           NaN        NaN  ...
# 42005                     NaN           NaN        NaN  ...
# 53282                     NaN           NaN        NaN  ...
# 53290                     NaN           NaN        NaN  ...
# 53347                     NaN           NaN        NaN  ...
# 55287                     NaN           NaN        NaN  ...
# 57828                     NaN           NaN        NaN  ...
# 59702                     NaN           NaN        NaN  ...
# 61554                     NaN           NaN        NaN  ...
# 62093                     NaN           NaN        NaN  ...
# 66598                     NaN           NaN        NaN  ...
# 66704                     NaN           NaN        NaN  ...
# 70983                     NaN           NaN        NaN  ...
#
#       beobachtung_wasserstand  \
# 3895                        -
# 4510                        -
# 8338                        -
# 10889                       -
# 13335                     NaN
# 13414                     NaN
# 13430                       -
# 17689                     NaN
# 19697                       -
# 22201                       -
# 24185                       -
# 24186                       -
# 31231                     NaN
# 33129                       -
# 35558                       -
# 39926                       -
# 39930                       -
# 42005                       -
# 53282                     NaN
# 53290                       -
# 53347                     NaN
# 55287                       -
# 57828                     NaN
# 59702                       -
# 61554                       -
# 62093                     NaN
# 66598                       -
# 66704                     NaN
# 70983                     NaN
#
#                                              eigentuemer  \
# 3895                                                 NaN
# 4510                                                 NaN
# 8338                                                 NaN
# 10889                                                NaN
# 13335                                                NaN
# 13414                                                NaN
# 13430                                                NaN
# 17689                                                NaN
# 19697                                                NaN
# 22201                                                NaN
# 24185                                                NaN
# 24186                                                NaN
# 31231                                                NaN
# 33129                                                NaN
# 35558                                                NaN
# 39926                                                NaN
# 39930                                                NaN
# 42005                                                NaN
# 53282                                                NaN
# 53290                                                NaN
# 53347                                                NaN
# 55287                                                NaN
# 57828  Wasserverband Siegen-Wittgenstein             ...
# 59702                                                NaN
# 61554                                                NaN
# 62093                                                NaN
# 66598                                                NaN
# 66704                                                NaN
# 70983                                                NaN
#
#                                                betreiber filterlaenge_cm  \
# 3895                                                 NaN             NaN
# 4510                                                 NaN             NaN
# 8338                                                 NaN             NaN
# 10889                                                NaN             NaN
# 13335                                                NaN             NaN
# 13414                                                NaN             NaN
# 13430                                                NaN             NaN
# 17689                                                NaN             NaN
# 19697                                                NaN             NaN
# 22201                                                NaN             NaN
# 24185                                                NaN             NaN
# 24186                                                NaN             NaN
# 31231                                                NaN             NaN
# 33129                                                NaN             NaN
# 35558                                                NaN             NaN
# 39926                                                NaN             NaN
# 39930                                                NaN             NaN
# 42005                                                NaN             NaN
# 53282                                                NaN             NaN
# 53290                                                NaN             NaN
# 53347                                                NaN             NaN
# 55287                                                NaN             NaN
# 57828  Wasserverband Siegen-Wittgenstein             ...             NaN
# 59702                                                NaN             NaN
# 61554                                                NaN             NaN
# 62093                                                NaN             NaN
# 66598                                                NaN             NaN
# 66704                                                NaN             NaN
# 70983                                                NaN             NaN
#
#       sumpfrohrlaenge_cm ausbaudurchmesser_mm historischer_ruhe_wsp  \
# 3895                 NaN                  NaN                   NaN
# 4510                 NaN                  NaN                   NaN
# 8338                 NaN                  NaN                   NaN
# 10889                NaN                  NaN                   NaN
# 13335                NaN                  NaN                   NaN
# 13414                NaN                  NaN                   NaN
# 13430                NaN                  NaN                   NaN
# 17689                NaN                  NaN                   NaN
# 19697                NaN                  NaN                   NaN
# 22201                NaN                  NaN                   NaN
# 24185                NaN                  NaN                   NaN
# 24186                0.0                  NaN                   NaN
# 31231                NaN                  NaN                   NaN
# 33129                NaN                  NaN                   NaN
# 35558                NaN                  NaN                   NaN
# 39926                NaN                  NaN                   NaN
# 39930                NaN                  NaN                   NaN
# 42005                NaN                  NaN                   NaN
# 53282                NaN                  NaN                   NaN
# 53290                NaN                  NaN                   NaN
# 53347                NaN                  NaN                   NaN
# 55287                NaN                300.0                   NaN
# 57828                NaN                  NaN                   NaN
# 59702                NaN                  NaN                   NaN
# 61554                NaN                  NaN                   NaN
# 62093                NaN                  NaN                   NaN
# 66598                NaN                  NaN                   NaN
# 66704                NaN                  NaN                   NaN
# 70983                NaN                  NaN                   NaN
#
#       einbaulaenge_cm oberkante_filter_cm unterkante_filter_cm
# 3895           2594.0              1945.0               1945.0
# 4510              NaN                 NaN                  NaN
# 8338           2179.0              2859.0               2859.0
# 10889          9065.0             -1974.0              -1974.0
# 13335             NaN                 NaN                  NaN
# 13414             NaN                 NaN                  NaN
# 13430             NaN                 NaN                  NaN
# 17689             NaN                 NaN                  NaN
# 19697           786.0              4713.0               4713.0
# 22201             NaN                 NaN                  NaN
# 24185         12450.0             -3710.0              -3710.0
# 24186           620.0              5400.0               5400.0
# 31231             NaN                 NaN                  NaN
# 33129         13110.0             -1111.0              -1111.0
# 35558             NaN                 NaN                  NaN
# 39926             NaN                 NaN                  NaN
# 39930             NaN                 NaN                  NaN
# 42005          2095.0              3164.0               3164.0
# 53282             NaN                 NaN                  NaN
# 53290             NaN                 NaN                  NaN
# 53347             NaN                 NaN                  NaN
# 55287          1267.0              4166.0               4166.0
# 57828             NaN                 NaN                  NaN
# 59702          2210.0              1789.0               1789.0
# 61554          8829.0               170.0                170.0
# 62093             NaN                 NaN                  NaN
# 66598             NaN                 NaN                  NaN
# 66704             NaN                 NaN                  NaN
# 70983             NaN                 NaN                  NaN
#
# [29 rows x 39 columns]

# %%
df.drop(df[df['e32'] < 100].index, inplace = True)
df.drop(df[df['n32'] < 100].index, inplace = True)

# %% [markdown]
# ### check externally
# in order to check the all rows externally we can write it in csv file

# %%
df.to_csv("test.csv", index = False)

# %% [markdown]
# Other columns have no problem and the data is ready to import to Database.

# %% [markdown]
# ## write in Database
# Now we want to import our df to postgres database.
#
# * First we have to connect to our Database URL
# * then we can write into the our database. we need to assign in which Schema we want to add our data frame. in this case I have added my data frame to the schema "hygrisc" which has been created before in the PGadmin.

# %%
# connect to out credential file

postgresurl = creds.URL

# %%
# write your sql url below
engine = sqlalchemy.create_engine(postgresurl)

# %%
# %time df.to_sql(con=engine, name="messstelle", schema="hygrisc", if_exists="replace", index=False)
# Out:
# CPU times: total: 9.39 s
# Wall time: 12.6 s
# 90

# %% [markdown]
# ### Create geometry columns
#
# Now everything is fine and our data has been imported to Database successfully. but still someting important is missing.
# We have e32 and new columns but in order to map these location correclty and exatly in QGIS, we need geometry information.
#
# in order to create geometry columns from n32 and e32 the follwing step is required.

# %%
quary = """ ALTER TABLE hygrisc.messstelle ADD COLUMN geom geometry(Point, 25832);
 UPDATE hygrisc.messstelle SET geom = ST_SetSRID(ST_MakePoint(e32, n32), 25832);"""

# %%
engine.execute(quary)
# Out:
# ---------------------------------------------------------------------------
# UndefinedObject                           Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# UndefinedObject: type "geometry" does not exist
# LINE 1:  ALTER TABLE hygrisc.messstelle ADD COLUMN geom geometry(Poi...
#                                                         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 engine.execute(quary)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedObject) type "geometry" does not exist
# LINE 1:  ALTER TABLE hygrisc.messstelle ADD COLUMN geom geometry(Poi...
#                                                         ^
#
# [SQL:  ALTER TABLE hygrisc.messstelle ADD COLUMN geom geometry(Point, 25832);
#  UPDATE hygrisc.messstelle SET geom = ST_SetSRID(ST_MakePoint(e32, n32), 25832);]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# Now everything is fine and the data has been imported to our database with geometry columns sucessfully. You can see the data in PGadmin as well.

# %% [markdown]
# ## Finish!
#
# That's great, You have imported the table successfully in Postgres Database.
